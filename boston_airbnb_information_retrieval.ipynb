# %%
# load library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import display
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
# import data
calendar = pd.read_csv('calendar.csv')
listings = pd.read_csv('listings.csv')
reviews = pd.read_csv('reviews.csv')

# %% [markdown]
# # Data Source
# https://www.kaggle.com/airbnb/boston

# %% [markdown]
# # Busiest Time In A Year?

# %%
# what does data look like
calendar.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
calendar.listing_id.nunique()
# Out:
# 3585

# %%
# clean price column:
## replace money sign and comma
calendar['price'] = calendar['price'].str.replace('$', '')
calendar['price'] = calendar['price'].str.replace(',', '')
calendar['price'] = calendar['price'].astype(float)

# %%
# clean duplicate data: id_12898806 has replicated data
calendar = calendar.drop_duplicates()

# %%
# change available from t/f to 1/0 so that I can aggregate count easily
calendar = calendar.replace({'available': {'t': 1, 'f': 0}})#

# %%
# derive month of the date
def month(row):
    return row['date'][5:7]

calendar['month'] = calendar.apply(lambda row: month(row), axis = 1)

# %%
# aggregation info I need: average price and availability of each month
## mean and median have similar pattern so just use mean
agg_price = calendar.groupby('month').agg({'price': ['mean'], 'available': ['sum']})

# %%
agg_price
# Out:
#             price available
#              mean       sum
# month
# 01     182.799671     63181
# 02     180.961028     56810
# 03     181.818742     55181
# 04     197.252890     51382
# 05     193.712295     53600
# 06     196.535302     52731
# 07     202.486309     54963
# 08     203.330142     55561
# 09     237.055387     33383
# 10     233.425228     46314
# 11     202.915712     58858
# 12     192.600118     60993

# %%
plt.figure(figsize=(12, 6))
plt.xlabel('Month')
plt.title('Price and Availability of AirBnB Listings in Boston')

ax1 = agg_price.iloc[:, 0].plot(color = 'blue', grid = True, label = 'Monthly Mean of Price')
ax2 = agg_price.iloc[:, 1].plot(color = 'red', grid = True, secondary_y = True, label = 'Availability')
# ax3 = agg_price.iloc[:, 1].plot(color = 'navy', grid = True, label = 'Median of Price')

for tl in ax2.get_yticklabels():
    tl.set_color('r')

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()


plt.legend(h1+h2, l1+l2, loc = 'upper center')
plt.show()

# %%
# aggregate by date
agg_price_daily = calendar.groupby('date').agg({'price': ['mean'], 'available': ['sum']})

plt.figure(figsize=(12, 6))
plt.xlabel('Date')
plt.title('Price and Availability of AirBnB Listings in Boston')

ax1 = agg_price_daily.iloc[:, 0].plot(color = 'blue', grid = True, label = 'Daily Mean of Price')
ax2 = agg_price_daily.iloc[:, 1].plot(color = 'red', grid = True, secondary_y = True, label = 'Availability')
# ax3 = agg_price.iloc[:, 1].plot(color = 'navy', grid = True, label = 'Median of Price')

for tl in ax2.get_yticklabels():
    tl.set_color('r')

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()


plt.legend(h1+h2, l1+l2, loc = 'upper center')
plt.show()

# %% [markdown]
# # Summary
# This calendar data has availability info of 3585 listings from 2016-09-06 to 2017-09-05. Since we do not have data that show whether each listing is rented or not, a listing is unavailable for two potential reasons:
#     1. The owner does not want to do this business on this day.
#     2. The listing is rented.
#
# Hence, we can only estimate the time when AirBnB in Boston is busy, by price and availability. When price increases and availability decreases, this signal indicates a busy time.
#
# Here are the findings:
#     1. Starting from September 2016, price decreases and availability increases, until early December 2016.
#     2. In early April, price has a sharp increase and availability has a sudden drop, which indicates a busy time.
#     3. This study can only represent the trend between Sep 2016 and Sep 2017 instead of overall seasonality. Further investigation is recommended to find out what cause the huge difference in availability between 2016-09-06 and 2017-09-05.
#
# Two potential reasons for the sudden drop in September:
#     1. More people are doing AirBnB business in 2017 than in 2016 hence customers have more new options and fewer people may choose the original listings.
#     2. Not all of these original 3585 listings start to do their AirBnB business from 2016-09-06, maybe some start to do business in Winter 2016.

# %% [markdown]
# # User Experience
# What do people like or dislike about their AirBnB journey in Boston?

# %%
# what does data look like
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
# read nlp library
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer

# %%
reviews.comments[0]
# Out:
# "My stay at islam's place was really cool! Good location, 5min away from subway, then 10min from downtown. The room was nice, all place was clean. Islam managed pretty well our arrival, even if it was last minute ;) i do recommand this place to any airbnb user :)"

# %%
# try nltk analyzer
# nltk analyzer classifies this text as negative...
blob = TextBlob(reviews.comments[0], analyzer = NaiveBayesAnalyzer())
blob.sentiment
# Out:
# Sentiment(classification='neg', p_pos=0.09723026115085937, p_neg=0.9027697388491426)

# %%
# decide to use default analyzer
blob = TextBlob(reviews.comments[0])
blob.sentiment
# Out:
# Sentiment(polarity=0.3880208333333333, subjectivity=0.7520833333333333)

# %%
# need to translate language, or non-english comment are always neutral/negative
## unable to translate all comments due to request limit
"""
text = '这里很不好'
blob = TextBlob(text)
blob.translate(to = 'en').polarity
"""
# Out:
# "\ntext = '这里很不好'\nblob = TextBlob(text)\nblob.translate(to = 'en').polarity\n"

# %%
# need to clean missing value
reviews = reviews.dropna(subset = ['comments'])
reviews = reviews.reset_index(drop = True)

# %%
# rate and classify polarity of each comment
polarity = []
polarity_class = []

for i in range(reviews.shape[0]):
    # print('we are dealing with the ' + str(i) + 'th comment: ' + reviews.comments[i])
    
    blob = TextBlob(reviews.comments[i])
    
    # translate to english
    ## unable to do it due to request limit
    # if blob.detect_language() != 'en':
    # blob = blob.translate(to = 'en')
    # time.sleep(0.1)
    
    polarity.append(blob.polarity)
        
    if blob.polarity > 0:
        polarity_class.append('positive')
        
    elif blob.polarity == 0:
        polarity_class.append('neutral')
            
    else:
        polarity_class.append('negative')
        
reviews['polarity'] = polarity
reviews['polarity_class'] = polarity_class

# %%
reviews.polarity.describe()
# Out:
# count    68222.000000
# mean         0.369697
# std          0.199060
# min         -1.000000
# 25%          0.256944
# 50%          0.368750
# 75%          0.483333
# max          1.000000
# Name: polarity, dtype: float64

# %%
reviews.polarity_class.value_counts()
# Out:
# positive    63693
# neutral      3658
# negative      871
# Name: polarity_class, dtype: int64

# %%
sns.catplot(x = 'polarity_class' , kind = 'count' , data = reviews)
plt.title('Comment Polarity of 68k AirBnB Reviews from Mar 2009 to Sep 2016')
# Out:
# Text(0.5, 1, 'Comment Polarity of 68k AirBnB Reviews from Mar 2009 to Sep 2016')

# %%
# positive tweets
reviews[reviews.polarity_class == 'positive']['comments'].head()
# Out:
# 0    My stay at islam's place was really cool! Good...
# 1    Great location for both airport and city - gre...
# 2    We really enjoyed our stay at Islams house. Fr...
# 3    The room was nice and clean and so were the co...
# 4    Great location. Just 5 mins walk from the Airp...
# Name: comments, dtype: object

# %%
reviews.comments[1]
# Out:
# 'Great location for both airport and city - great amenities in the house: Plus Islam was always very helpful even though he was away'

# %%
# neutral tweets
reviews[reviews.polarity_class == 'neutral']['comments'].head()
# Out:
# 12    Mi estadía en Boston aunque corta fue muy buen...
# 50    La maison située dans East Boston était sympat...
# 55    De kamer wordt verhuurd via een "self-check in...
# 65                              had everything needed!
# 83    Una casa muy acogedora, muy cerca (a menos de ...
# Name: comments, dtype: object

# %%
reviews.comments[65]
# Out:
# 'had everything needed! '

# %%
# negative tweets
reviews[reviews.polarity_class == 'negative']['comments'].head()
# Out:
# 20    Izzy was a nice and helpful host with detailed...
# 24    We didn´t meet Izzy at all!!!! After we arrive...
# 46    Izzy's home is conveniently located for anyone...
# 59    Hard tofind parking.  One night's sleep is alr...
# 64    Parking situation was bad.  Very hard to find ...
# Name: comments, dtype: object

# %%
# fn
reviews.comments[20]
# Out:
# 'Izzy was a nice and helpful host with detailed directions. The room is in the basement and even though Izzy mentions it we somehow missed that detail and it has narrow stairs leading down to it which made it hard for us to carry our bags up and down. We are unfortunately traveling with really heavy bags. The place is in East Boston and is extremely convenient for the airport.'

# %%
reviews.comments[24]
# Out:
# 'We didn´t meet Izzy at all!!!! After we arrived nobody was there except some spanish speaking people.\r\nOur room was disgusting!!! It smelted like mold and was very dirty!!!!\r\nThe Bathroom wasn´t cleaned either and my friend and i wanted to leave right after we came…\r\nThe Dryer or washer was not usable because the assistant from Izzy washed all the time.\r\nThe Neighborhood is not safe at all and every other morning u could hear people fight.\r\nDon´t stay there!!!!!! It´s nothing like u would expect it! \r\nAnd it´s defenetly to expensive for this nasty place!!!! '

# %%
# ngram function
from collections import defaultdict
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer 

stopwords = set(stopwords.words( 'english' ))
more_stopwords = set(['would', 'definitely', 'place', 'stay', 'us', 'recommend'])
stopwords = stopwords.union(more_stopwords)

def generate_ngrams(df, col, n_gram, max_row):
    temp_dict = defaultdict(int)
    for text in df[col]:
        for word in ngram_extractor(text, n_gram):
            temp_dict[word] += 1
    temp_df = pd.DataFrame(sorted(temp_dict.items(), key=lambda x: x[1])[::-1]).head(max_row)
    temp_df.columns = ["word", "wordcount"]
    return temp_df

def ngram_extractor(text, n_gram):
    tokens = wc_tokenize(text)
    tokens = remove_stopword(tokens)
    tokens = lemmatized_tokens(tokens)
    ngrams = zip(*[tokens[i:] for i in range(n_gram)])
    return [" ".join(ngram) for ngram in ngrams]

def wc_tokenize(text):
    tokens = []
    
    # tokenize
    ## transfer text in string to lowercase
    text = text.lower()
    
    ## replace non alpha/digit character with whitespace
    for character in text:
        if not(character.isalpha() or character.isdigit()):
            text = text.replace(character, ' ')
    
    ## split with space
    text = text.split(' ')
    for token in text:
        if token != '':
            tokens.append(token)
            
    return tokens
            
def remove_stopword(tokens):
    tokens_nostopword = []
    
    for token in tokens:
        if not token in stopwords:
            tokens_nostopword.append(token)
            
    return tokens_nostopword

def stem_tokens(tokens):
    stemmed_tokens = []
    ps = PorterStemmer()
    
    for token in tokens:
        stemmed_tokens.append(ps.stem(token))
    
    return stemmed_tokens

def lemmatized_tokens(tokens):
    lemmatized_tokens = []
    lemmatizer = WordNetLemmatizer()
    
    for token in tokens:
        lemmatized_tokens.append(lemmatizer.lemmatize(token, pos = 'v'))
    
    return lemmatized_tokens

# %%
# visualize ngrams word count output
import seaborn as sns

def top_words(df):
    plt.figure(figsize=(12,8))
    sns.barplot(df["wordcount"], df["word"])
    plt.xlabel("Word Count", fontsize = 15)
    plt.ylabel("Terms", fontsize = 15)
    plt.title("Top Words In Reviews")
    plt.show()

# %%
# function to detect non-english comment
from nltk.corpus import words

def non_english(text):
    tokens = wc_tokenize(text)
    tokens = lemmatized_tokens(tokens)
    # print(tokens)
    
    if len(tokens) < 3:
        return False
    elif tokens[0] in words.words() and tokens[1] in words.words() and tokens[2] in words.words():
        return False
    
    return True

# %%
non_english("While others have had great experiences")
# Out:
# True

# %%
"others" in words.words()
# Out:
# False

# %%
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize('financing', pos = 'v')
# Out:
# 'finance'

# %%
# exclude non-english negative comments for better word counts
## loop each comment, tokenize, test if first 3 words are all in is english
reviews_negative = reviews[reviews.polarity_class == 'negative']
reviews_negative = reviews_negative.reset_index(drop = True)
reviews_negative.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     1178162  11901870  2014-04-18       578962         Samir
# 1     1178162  12753057  2014-05-10     14113353         Chris
# 2     1178162  18696958  2014-08-30     15346724       Stephen
# 3     1178162  21303347  2014-10-14     21630508         Linda
# 4     1178162  21809402  2014-10-24     22554506        Claude
#
#                                             comments  polarity polarity_class
# 0  Izzy was a nice and helpful host with detailed... -0.069753       negative
# 1  We didn´t meet Izzy at all!!!! After we arrive... -0.507542       negative
# 2  Izzy's home is conveniently located for anyone... -0.018182       negative
# 3  Hard tofind parking.  One night's sleep is alr... -0.097222       negative
# 4  Parking situation was bad.  Very hard to find ... -0.225045       negative

# %%
# main loop to detect non-english comment
for i in range(reviews_negative.shape[0]):
    if non_english(reviews_negative.comments[i]):
        reviews_negative.loc[i, 'polarity'] = np.nan
        reviews_negative.loc[i, 'polarity_class'] = 'non english'

# %%
reviews_negative.iloc[0:100, ]
# Out:
#     listing_id        id        date  reviewer_id  reviewer_name  \
# 0      1178162  11901870  2014-04-18       578962          Samir
# 1      1178162  12753057  2014-05-10     14113353          Chris
# 2      1178162  18696958  2014-08-30     15346724        Stephen
# 3      1178162  21303347  2014-10-14     21630508          Linda
# 4      1178162  21809402  2014-10-24     22554506         Claude
# 5      1178162  94675484  2016-08-16     17356185         Giulia
# 6         9857  14951136  2014-06-30     11434319          David
# 7      3992208  19488134  2014-09-13     19641034            Max
# 8      3992208  20706874  2014-10-04     10291988      Géraldine
# 9      3992208  36082180  2015-06-25     26120265            Ann
# 10     3992208  36853306  2015-07-02     24767999           Anne
# 11     3992208  37545588  2015-07-08      1740551           Joan
# 12     3992208  65017768  2016-03-10     13937282            Pit
# 13     3992208  66147617  2016-03-20     50597495        Mariano
# 14     3992208  81191342  2016-06-21     42189072           Jody
# 15     3992208  92913574  2016-08-10     37521840          Fidji
# 16     4287366  74457048  2016-05-15     33224631          Beans
# 17    11986653  76516978  2016-05-27     69325098          Katie
# 18      951476   6759919  2013-08-24       148789           Adam
# 19     2526773  25210822  2015-01-09     25077446           Mark
# 20     6314998  91475870  2016-08-05     79392165           Mike
# 21     1321422  29678010  2015-04-11     28910648           Arth
# 22     8624898  52622338  2015-10-31     42903844        Manfred
# 23     8624898  70786016  2016-04-20     51257470           Hong
# 24     8624898  82931500  2016-06-30     57259540        Richard
# 25     8624898  95429627  2016-08-19     55801278         Jasmin
# 26     1497879  35249802  2015-06-16      2621548           Jill
# 27     1497879  45990030  2015-09-07     38097423          Annie
# 28     1497879  47359077  2015-09-18         8267           Erin
# 29     1497879  49978061  2015-10-08     36978343         Antish
# 30     1497879  52211855  2015-10-27     10604919           Kepa
# 31     1497879  56095968  2015-12-08     40941541           Alex
# 32     1497879  71540909  2016-04-26     34759008           Mike
# 33     1497879  83964297  2016-07-04     61434345        Vanessa
# 34     8930592  77821742  2016-06-03     11877584         Pieter
# 35     4924009  29486746  2015-04-08     15390410       Victoria
# 36     4924009  33505675  2015-05-29     30282678          Chris
# 37     4924009  56545996  2015-12-14     50367317           Juan
# 38     4924009  59569666  2016-01-12     48187490         Matías
# 39     4967219  50830257  2015-10-15     34398324     Pierre-Luc
# 40     4967219  53161213  2015-11-05     42527770        Zachery
# 41     4967219  57800504  2015-12-29     43778329       Songyuan
# 42     4967219  59808704  2016-01-15      9841755           Long
# 43     4967219  93564934  2016-08-13     49571617           Jing
# 44     1197857  19468551  2014-09-13      7288926      Catherine
# 45    13546414  90839962  2016-08-02     77763544           Stef
# 46     4304969  25290995  2015-01-11     24480929        Nicolas
# 47    11593592  73198789  2016-05-07     47203142         Ursula
# 48    11902134  92308919  2016-08-08      4717222           Reba
# 49     5991427  30266566  2015-04-19     31306237        Yannick
# 50     5991427  32615296  2015-05-19     32876527         Dyanne
# 51     5991427  33192181  2015-05-25     10927211          Hervé
# 52     5991427  38059535  2015-07-12     37402701   Marie-Hélène
# 53     2278704  22935733  2014-11-17     22848493          Taryn
# 54    10881994  77771418  2016-06-03      9687492      Elisabeth
# 55     5940866  43042899  2015-08-17     18263319        Martina
# 56    10266928  60721952  2016-01-26     49185028         Monica
# 57     1803138  44920696  2015-08-30     34530786  Meike Cathrin
# 58     2947662  35311457  2015-06-17     29048403          Jesus
# 59    11462476  91470629  2016-08-05      2141273         Meghan
# 60     1525494  32551958  2015-05-19     31394301         Joshua
# 61     1525494  34092771  2015-06-04     34002305        Jessika
# 62     1167221  65723692  2016-03-16     26489170          Julie
# 63     3616081  69666710  2016-04-12     18876213        Deborah
# 64    10995976  77239349  2016-05-30     38102640         Ingrid
# 65    10995976  90901137  2016-08-02     40716354           René
# 66     7245413  45268024  2015-09-01     38064754    Mehmet Emin
# 67     4149974  43351696  2015-08-19     15933074   Massimiliano
# 68     4149974  66025530  2016-03-19     46286575       Stefanie
# 69     6006328  84635273  2016-07-08     20870118      Alexandre
# 70     6006328  89796838  2016-07-30     75437004        Matthew
# 71     8649257  68363701  2016-04-04     14786850       Aniruddh
# 72     3601424  45953598  2015-09-07     34796664       Chingyun
# 73     3601424  48403193  2015-09-26     37149618        Aurélia
# 74    10056496  82966441  2016-06-30     48363967         Ashley
# 75    10056496  89465033  2016-07-28     41009647           Chen
# 76       60029    168181  2011-01-08       257098            Ana
# 77       60029  21025395  2014-10-10     12798354       Minh-Thi
# 78     6014302  73092306  2016-05-06     64959539       Eleonora
# 79     5729845  32413508  2015-05-17     30975673            Ari
# 80     6780300  53188610  2015-11-06     13496993          Tegan
# 81     2776143  15572949  2014-07-12     12216664  Jean-François
# 82     2776143  27312211  2015-03-01      3695323           Ruth
# 83     2776143  28784408  2015-03-30     21635649        Jessica
# 84     2776143  33499241  2015-05-29      7555316        Antoine
# 85     2776143  34268949  2015-06-07     12517504         Carrie
# 86     2776143  35447316  2015-06-19      2396477         Laurie
# 87     2776143  50071448  2015-10-09     39560772           Sean
# 88     2776143  50968485  2015-10-16      8725607         Leslie
# 89     2776143  57866954  2015-12-30     26697045  Alyana & Ryan
# 90     2776143  62037450  2016-02-10     11005287          Lucas
# 91     2776143  64054364  2016-02-29     53031235      Meritxell
# 92     2776143  95954634  2016-08-21     68417017       Kimberly
# 93     4278873  30387585  2015-04-21       759970           Roni
# 94     8420883  64969248  2016-03-09      9047734        Stephan
# 95     2301709  29547304  2015-04-09     20835894         Renaud
# 96     4080000  20727225  2014-10-04     21702197         Olivia
# 97     4080000  21812057  2014-10-24     22715640        Quentin
# 98     4080000  24714588  2015-01-02       552500     Thanachart
# 99     4080000  40293596  2015-07-29      3945733      Christina
#
#                                              comments  polarity polarity_class
# 0   Izzy was a nice and helpful host with detailed...       NaN    non english
# 1   We didn´t meet Izzy at all!!!! After we arrive...       NaN    non english
# 2   Izzy's home is conveniently located for anyone...       NaN    non english
# 3   Hard tofind parking.  One night's sleep is alr...       NaN    non english
# 4   Parking situation was bad.  Very hard to find ... -0.225045       negative
# 5   nothing what I expected !\nwe start from the p... -0.456888       negative
# 6   Apartment is small, but was well located and f... -0.060000       negative
# 7   The apartment is really close to the places to... -0.021875       negative
# 8   Sean's appartement was as described, very well...       NaN    non english
# 9   We were rather disappointed with this accommod... -0.103030       negative
# 10  Lille lejlighed tæt på byen. Vi boede tre menn...       NaN    non english
# 11  disgusting, disappointed, dirty. The two matre... -0.337500       negative
# 12  The apartment was disappointing compared to th... -0.366667       negative
# 13  I was in the department 4. The apartment was d... -0.257000       negative
# 14  I have used airbnb enough to come to expect a ... -0.146811       negative
# 15  L'appartement est bien situé dans un quartier ...       NaN    non english
# 16  WOULD NOT RECOMMEND FOR ANYONE\r\nCourtney had... -0.093611       negative
# 17  Place looked nothing like what is portrayed in... -0.110556       negative
# 18  While others have had great experiences with S...       NaN    non english
# 19  This apartment had everything we needed and wa... -0.041111       negative
# 20  This is a room only. Big and clean just a bit ... -0.033333       negative
# 21  The host was extremely welcoming. Gave us usef... -0.017000       negative
# 22  We stayed at Jordan´s place for 2 nights. He w... -0.035162       negative
# 23  The house location is very convienent,easy to ... -0.275000       negative
# 24  Very disappointed doesn't begin to explain how...       NaN    non english
# 25  We were very disappointed. On the pictures the... -0.052222       negative
# 26  The studio was in the basement and it was not ... -0.107426       negative
# 27  The host is a nice lady. But the room is in th... -0.028333       negative
# 28  This host is very organized and accommodating.... -0.150000       negative
# 29  Pros:\n1. Well located - a few stops from down...       NaN    non english
# 30  Despite the good location and the attractions ... -0.100476       negative
# 31  Sara was helpful and accommodating. The room i...       NaN    non english
# 32  Cozy little place to stay. We used an Uber to ... -0.010833       negative
# 33  The apartment is very close to an mbta station... -0.043056       negative
# 34  We found the apartment as described and it was... -0.062500       negative
# 35  We have some positive things about this apartm... -0.030348       negative
# 36  Communication with host was good. It should be... -0.232589       negative
# 37  NEGATIVES.\r\n1) I never met Ahmed, only Eddie...       NaN    non english
# 38  Check in at 3pm was very punctual. The neighbo... -0.148872       negative
# 39  We stayed at Anthony’s place for 4 nights. It ... -0.128833       negative
# 40  this was falsely advertised, and arguably the ... -0.261111       negative
# 41  It was really cold outside when I was in Bosto... -0.154688       negative
# 42  I have used airbnb for almost 3 years, either ... -0.044854       negative
# 43  The room is sunny and there is a separate frid... -0.078365       negative
# 44  Well situated and very clean but quite expensi... -0.007778       negative
# 45  This was really a bad place. It was run down, ... -0.199653       negative
# 46  L'appartement est spacieux, en très bon état, ...       NaN    non english
# 47   Lana was very welcoming despite a late arrival.        NaN    non english
# 48  HoSt answered all texts in a timely fashion & ... -0.212857       negative
# 49  Carols and her family were very friendly and t... -0.016667       negative
# 50  The neighborhood was very quiet and residentia... -0.066667       negative
# 51  This place is in fact a hostel that Carols cre... -0.009524       negative
# 52  La chambre était très propre est bien rangée, ...       NaN    non english
# 53  Cynthia was greeting us even before we arrive ...       NaN    non english
# 54  L'appartement est bien situé dans Boston. Ceci...       NaN    non english
# 55  Valerie und Jason waren sehr freundlich. Bei d...       NaN    non english
# 56  This place was in a beautiful area of Boston. ... -0.136111       negative
# 57  Unser Aufenthalt bei Pam und Sara war wundersc...       NaN    non english
# 58  Desde el principio Lev fue un anfitrión muy at...       NaN    non english
# 59  I stayed in Christopher's flat for a business ... -0.008333       negative
# 60  During our trip, Ari was out of town; however,... -0.025000       negative
# 61  Unfortunately we changed our travel plans and ... -0.250000       negative
# 62  Die Suite war wirklich sehr sehr schön und ges... -0.250000       negative
# 63  Andrea cares a lot about hosting, and offered ...       NaN    non english
# 64  Notre hôte est arrivé en retard de 20mn. Ensui...       NaN    non english
# 65  Seif was very polite and concerned about us. T...       NaN    non english
# 66  Air condition and wifi were terrible also home... -0.800000       negative
# 67  Abbiamo soggiornato a casa di Joe e Ayad purtr...       NaN    non english
# 68  Obwohl wir Joe nicht persönlich getroffen habe...       NaN    non english
# 69  We did not meet Eric, but we met his mother wh... -0.102857       negative
# 70  This was a horrible experience.  My family and... -0.151780       negative
# 71  It advertises that street parking is available... -0.149107       negative
# 72  Feel really sorry about checking out 30 minute... -0.150000       negative
# 73  Nous avons passé un très bon séjour. L'accueil...       NaN    non english
# 74  Our AirBnB experience began with a man coming ...       NaN    non english
# 75  The apartment we rent is in the half-basement ... -0.170323       negative
# 76  We spent a night at Michelle's place. Her plac... -0.017073       negative
# 77  Very unpleasant experience. Michelle accused m... -0.010556       negative
# 78  The house was not exactly what we expected to ... -0.090152       negative
# 79  The Host was horrible and he (URL HIDDEN) i'm ... -0.201667       negative
# 80  The place was clean and as described. I never ... -0.092708       negative
# 81  La vétusté de la chambre et l'absence de propr...       NaN    non english
# 82  Sean was accommodating when I made a somewhat ...       NaN    non english
# 83  This place will do, but it's not amazing. Beac... -0.096429       negative
# 84  The location is great, at the heart of Beacon ... -0.078125       negative
# 85  This is my fifth time using Airbnb. I've had t... -0.032353       negative
# 86  Sean explained how things worked and explained...       NaN    non english
# 87  Sean was accommodating to an early check-in, w...       NaN    non english
# 88  Sean was very helpful and responsive throughou...       NaN    non english
# 89  Sean was a very responsive host. He answered o...       NaN    non english
# 90  Overall our experience was decent. The locatio... -0.034848       negative
# 91  Extremely well located but poorly maintained a... -0.375000       negative
# 92  My coworker and I stayed at Sean’s place this ...       NaN    non english
# 93  Cindy is a gracious and generous host.   At th...       NaN    non english
# 94  We made arrangement to our clients at Margarit... -0.050000       negative
# 95  L'appartement est conforme aux photos. Il est ...       NaN    non english
# 96  This was my first experience using Airbnb . I ... -0.032893       negative
# 97  Très jolie maison \nBelle chanbre très propre ...       NaN    non english
# 98  The place's quality is average for this price ... -0.077778       negative
# 99  Well, you get what you pay for and unfortunate... -0.004762       negative

# %%
# drop non english negative
reviews_negative = reviews_negative.dropna(subset = ['polarity'])
reviews_negative = reviews_negative.reset_index(drop = True)

# %%
# ngrams word count of positive and negative
reviews_positive = reviews[reviews.polarity_class == 'positive']
ngrams_positive1 = generate_ngrams(reviews_positive, 'comments', 1, 20)
ngrams_positive2 = generate_ngrams(reviews_positive, 'comments', 2, 20)
ngrams_positive3 = generate_ngrams(reviews_positive, 'comments', 3, 20)

ngrams_negative1 = generate_ngrams(reviews_negative, 'comments', 1, 20)
ngrams_negative2 = generate_ngrams(reviews_negative, 'comments', 2, 20)
ngrams_negative3 = generate_ngrams(reviews_negative, 'comments', 3, 20)

# %%
top_words(ngrams_positive1)

# %%
top_words(ngrams_positive2)

# %%
top_words(ngrams_positive3)

# %%
top_words(ngrams_negative1)

# %%
top_words(ngrams_negative2)

# %%
top_words(ngrams_negative3)

# %% [markdown]
# # Summary
# The review data includes 68k comments from to 2009-03-21 to 2016-09-06.
#
# ### Mostly Mentioned In Positive Reviews
# 1. a convenient location with a high walking score
# 2. a clean apartment
# 3. a great host that make visitors feel welcomed
#
# ### Mostly Mentioned In Negative Reviews
# 1. dirty kitchen...
# 2. bad communication
#
# ### Further Improvement
# 1. translate non-English comment and dig into more info
# 2. improve non-English filter

# %% [markdown]
# # What are vibe of each neighborhood in Boston

# %%
listings.loc[0:100, ['host_neighbourhood', 'neighbourhood']]
# Out:
#     host_neighbourhood  neighbourhood
# 0           Roslindale     Roslindale
# 1           Roslindale     Roslindale
# 2           Roslindale     Roslindale
# 3                  NaN            NaN
# 4           Roslindale     Roslindale
# 5           Roslindale     Roslindale
# 6           Roslindale            NaN
# 7           Roslindale     Roslindale
# 8           Roslindale     Roslindale
# 9           Roslindale     Roslindale
# 10          Roslindale     Roslindale
# 11          Roslindale     Roslindale
# 12          Roslindale     Roslindale
# 13          Roslindale     Roslindale
# 14          Roslindale     Roslindale
# 15          Roslindale     Roslindale
# 16          Roslindale     Roslindale
# 17          Roslindale     Roslindale
# 18          Roslindale     Roslindale
# 19          Roslindale            NaN
# 20          Roslindale     Roslindale
# 21          Roslindale     Roslindale
# 22          Roslindale     Roslindale
# 23                 NaN            NaN
# 24          Roslindale     Roslindale
# 25          Roslindale     Roslindale
# 26          Roslindale     Roslindale
# 27          Roslindale     Roslindale
# 28          Roslindale     Roslindale
# 29          Roslindale     Roslindale
# 30          Roslindale     Roslindale
# 31          Roslindale     Roslindale
# 32          Roslindale     Roslindale
# 33          Roslindale     Roslindale
# 34          Roslindale     Roslindale
# 35          Roslindale     Roslindale
# 36                 NaN            NaN
# 37          Roslindale     Roslindale
# 38          Roslindale     Roslindale
# 39          Roslindale     Roslindale
# 40          Roslindale     Roslindale
# 41          Roslindale     Roslindale
# 42          Roslindale     Roslindale
# 43          Roslindale     Roslindale
# 44          Roslindale     Roslindale
# 45          Roslindale     Roslindale
# 46          Roslindale     Roslindale
# 47          Roslindale     Roslindale
# 48          Roslindale     Roslindale
# 49          Roslindale     Roslindale
# 50          Roslindale     Roslindale
# 51          Roslindale     Roslindale
# 52          Roslindale     Roslindale
# 53          Roslindale     Roslindale
# 54                 NaN            NaN
# 55          Roslindale     Roslindale
# 56       Jamaica Plain  Jamaica Plain
# 57       Jamaica Plain  Jamaica Plain
# 58       Jamaica Plain  Jamaica Plain
# 59       Jamaica Plain  Jamaica Plain
# 60       Jamaica Plain  Jamaica Plain
# 61       Jamaica Plain  Jamaica Plain
# 62       Jamaica Plain  Jamaica Plain
# 63       Jamaica Plain  Jamaica Plain
# 64                 NaN            NaN
# 65       Jamaica Plain  Jamaica Plain
# 66       Jamaica Plain  Jamaica Plain
# 67       Jamaica Plain  Jamaica Plain
# 68       Jamaica Plain  Jamaica Plain
# 69       Jamaica Plain  Jamaica Plain
# 70       Jamaica Plain  Jamaica Plain
# 71       Jamaica Plain  Jamaica Plain
# 72       Jamaica Plain  Jamaica Plain
# 73       Jamaica Plain  Jamaica Plain
# 74       Jamaica Plain  Jamaica Plain
# 75       Jamaica Plain  Jamaica Plain
# 76       Jamaica Plain  Jamaica Plain
# 77       Jamaica Plain  Jamaica Plain
# 78       Jamaica Plain  Jamaica Plain
# 79       Jamaica Plain  Jamaica Plain
# 80       Jamaica Plain  Jamaica Plain
# 81       Jamaica Plain  Jamaica Plain
# 82       Jamaica Plain  Jamaica Plain
# 83       Jamaica Plain  Jamaica Plain
# 84       Jamaica Plain  Jamaica Plain
# 85       Jamaica Plain  Jamaica Plain
# 86       Jamaica Plain  Jamaica Plain
# 87       Jamaica Plain  Jamaica Plain
# 88           Hyde Park            NaN
# 89       Jamaica Plain  Jamaica Plain
# 90       Jamaica Plain  Jamaica Plain
# 91       Jamaica Plain  Jamaica Plain
# 92       Jamaica Plain  Jamaica Plain
# 93       Jamaica Plain  Jamaica Plain
# 94                 NaN            NaN
# 95       Jamaica Plain  Jamaica Plain
# 96       Jamaica Plain  Jamaica Plain
# 97       Jamaica Plain  Jamaica Plain
# 98       Jamaica Plain  Jamaica Plain
# 99       Jamaica Plain  Jamaica Plain
# 100      Jamaica Plain  Jamaica Plain

# %%
# host neighborhood means the location of the host? and neighborhood is the real listing location?
listings.neighbourhood.value_counts()
# Out:
# Allston-Brighton      364
# Jamaica Plain         314
# South End             298
# Back Bay              291
# Fenway/Kenmore        249
# South Boston          216
# Dorchester            195
# Beacon Hill           174
# North End             125
# East Boston           117
# Roxbury               116
# Mission Hill          103
# Charlestown            79
# Chinatown              78
# West End               68
# Roslindale             50
# West Roxbury           35
# Theater District       33
# Downtown Crossing      26
# Hyde Park              25
# Mattapan               20
# Financial District     13
# Somerville             13
# Downtown                8
# Brookline               8
# Leather District        8
# Cambridge               7
# Chestnut Hill           4
# Government Center       3
# Harvard Square          2
# Name: neighbourhood, dtype: int64

# %%
# lets select the top 3 most popular neighborhood and count words in their description
## column: neighborhood_overview
## 1st: Allston-Brighton
## 2nd: Jamaica Plain
## 3rd: South End
AB = listings[listings.neighbourhood == 'Allston-Brighton']
JP = listings[listings.neighbourhood == 'Jamaica Plain']
SE = listings[listings.neighbourhood == 'South End']

# %%
AB_nonan = AB.dropna(subset = ['neighborhood_overview'])
AB_2grams = generate_ngrams(AB_nonan, 'neighborhood_overview', 2, 20)
top_words(AB_2grams)

# %%
top_words(AB_2grams)

# %%
JP_nonan = JP.dropna(subset = ['neighborhood_overview'])
JP_2grams = generate_ngrams(JP_nonan, 'neighborhood_overview', 2, 20)
top_words(JP_2grams)

# %%
SE_nonan = SE.dropna(subset = ['neighborhood_overview'])
SE_2grams = generate_ngrams(SE_nonan, 'neighborhood_overview', 2, 20)
top_words(SE_2grams)

# %%
top_words(SE_2grams)
